# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
data = pd.read_excel('1.xlsx')
data
# Out:
#            date         time  PM2.5_CF1_ug/m3  PM10.0_CF1_ug/m3  \
# 0    2022-01-13  00:00:00 UT           104.17            118.00
# 1    2022-01-14  00:00:00 UT            60.31             64.73
# 2    2022-01-15  00:00:00 UT           143.23            159.87
# 3    2022-01-16  00:00:00 UT            43.28             46.33
# 4    2022-01-17  00:00:00 UT           117.65            130.44
# ...         ...          ...              ...               ...
# 3724 2022-08-27  23:00:00 UT            16.95             19.61
# 3725 2022-08-28  23:00:00 UT            20.49             23.32
# 3726 2022-08-29  23:00:00 UT            69.18             75.66
# 3727 2022-08-30  23:00:00 UT            43.14             47.48
# 3728 2022-08-31  23:00:00 UT             4.54              5.36
#
#       Temperature_F  Humidity_%
# 0             89.00       65.23
# 1             88.23       63.00
# 2             89.10       65.23
# 3             88.57       69.97
# ...

# %%
data.notnull
# Out:
# <bound method DataFrame.notnull of            date         time  PM2.5_CF1_ug/m3  PM10.0_CF1_ug/m3  \
# 0    2022-01-13  00:00:00 UT           104.17            118.00
# 1    2022-01-14  00:00:00 UT            60.31             64.73
# 2    2022-01-15  00:00:00 UT           143.23            159.87
# 3    2022-01-16  00:00:00 UT            43.28             46.33
# 4    2022-01-17  00:00:00 UT           117.65            130.44
# ...         ...          ...              ...               ...
# 3724 2022-08-27  23:00:00 UT            16.95             19.61
# 3725 2022-08-28  23:00:00 UT            20.49             23.32
# 3726 2022-08-29  23:00:00 UT            69.18             75.66
# 3727 2022-08-30  23:00:00 UT            43.14             47.48
# 3728 2022-08-31  23:00:00 UT             4.54              5.36
#
#       Temperature_F  Humidity_%
# 0             89.00       65.23
# 1             88.23       63.00
# 2             89.10       65.23
# ...

# %%
#quicklook
data.groupby('time')['PM2.5_CF1_ug/m3'].mean().plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
hourly_pm = data.groupby('time')['PM2.5_CF1_ug/m3'].mean()

# %%
fig = plt.figure(figsize=(10,5))
plt.plot(data.time.unique(),hourly_pm,color='black')
plt.xlabel('TIME')
plt.ylabel('PM2.5_CF1_ug/m3')
plt.title('HOURLY DISTRIBUTION OF PM2.5')
plt.xticks(rotation=45);

plt.savefig('visuals/HOURLY DISTRIBUTION OF PM2.5.png',dpi = 300,facecolor='w', pad_inches=0.1)
# Out:
# C:\Users\Theophilus Bassaw\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1207: UnknownTimezoneWarning: tzname UT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# C:\Users\Theophilus Bassaw\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1207: UnknownTimezoneWarning: tzname UT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "

# %%
hourly_pm10=data.groupby('time')['PM10.0_CF1_ug/m3'].mean()

# %%
fig = plt.figure(figsize=(10,5))
plt.plot(data.time.unique(),hourly_pm10,color='black')
plt.xlabel('TIME')
plt.ylabel('PM10.0_CF1_ug/m3')
plt.title('HOURLY DISTRIBUTION OF PM10')
plt.xticks(rotation = 45);

plt.savefig('visuals/HOURLY DISTRIBUTION OF PM10.png',dpi = 300,facecolor='w', pad_inches=0.1)
# Out:
# C:\Users\Theophilus Bassaw\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1207: UnknownTimezoneWarning: tzname UT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# C:\Users\Theophilus Bassaw\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1207: UnknownTimezoneWarning: tzname UT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
